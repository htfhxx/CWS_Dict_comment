# %%
import numpy as np
import codecs
import random
import os
import re
import collections
from gensim.models import word2vec

from tempfile import mkstemp

# %%
data=[]
dataset='pku'

# %%
f1 = codecs.open("data/%s_train" % (dataset), "r", 'utf-8')
f2 = codecs.open("data/%s_test" % (dataset), "r", 'utf-8')
f3 = codecs.open("data/%s_dev" % (dataset), "r", 'utf-8')

# %%
data.extend([list("".join(line.split())) for line in f1.readlines()])
data.extend([list("".join(line.split())) for line in f1.readlines()])
data.extend([list("".join(line.split())) for line in f1.readlines()])

# %%
print(type(data))
# Out:
# <class 'list'>

# %%
model = word2vec.Word2Vec(data, size=100, workers=4, min_count=1, window=8, iter=20)

# %%
print(model)
# Out:
# Word2Vec(vocab=4486, size=100, alpha=0.025)

# %%
model.save('data\\gensim_word2vec_100')

# %%
# Out:
# C:\Users\HELLO_~1\AppData\Local\Temp\tmpmejjtf9zgensim_word2vec_100
